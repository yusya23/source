# %% [markdown]
# 図で見る主成分分析

# %%
# 前回のプログラムの読込
# %run 3.ipynb
trans_data.shape
# Out:
# (200, 200)

# %%
def show_image(result,i):
    plt.imshow(result.components_[i].reshape(28,28),cmap='gray')

# %%
show_image(result,0)

# %%
show_image(result,1)

# %%
show_image(result,2)

# %%
show_image(result,3)

# %%
show_image(result,4)
